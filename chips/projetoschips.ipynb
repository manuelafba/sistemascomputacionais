# %%
from IPython.display import Image
Image(filename=r'C:\Users\desk\Pictures\projeto1.png')

# %% [raw]
# Capacidade da memória = 8gbits
# 8Gbits = 2^33
# 13 pinos = 13 bits de endereço
# O BD não pode exceder 64 bits e a palavra deve ser maior que a célula da memória
# Considerando que o BD tem 64 bits e transporta 2 palavras por vez, cada palavra tem 32 bits
# Cada célula vai ter 16 bits, pois ela deve ser menor que a palavra
# Considerando que no chip temos uma matriz quadrada 13x13 (13 = bits de endereço), RAS e CAS = 2^13
# Temos: 2^33 = 2^13 . 2^13 . 2^4
# Faltam 3 unidades no expoente para completar 33, logo teremos 2^3 bancos
# 2^3 . 2^13 . 2^13 = 2^29 = 512Mb
#
# BE: 13 bits
# BD: 64 bits
# Palavra: 32 bits
# Célula: 16 bits

# %%
from IPython.display import Image
Image(filename=r'C:\Users\desk\Pictures\projeto2.png')

# %% [raw]
# O chip tem no total 32Gbits
# 32Gbits = 2^35
# BD = 16 linhas de dados = 2^4
# Os pinos de endereço devem ser menores que 14, considerei o máximo (13) e uma matriz quadrada 13x13
# Temos: 2^35 = 2^13 . 2^13 . 2^4
# Faltam 5 unidades para completar 35, logo teremos 2^5 bancos
# 2^5 . 2^13 . 2^13 = 2^31 = 1Gb
#
# BE: 13 bits
# BD: 16 bits
# Célula: 16 bits
